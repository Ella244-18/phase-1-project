# %% [markdown]
# <a href="https://colab.research.google.com/github/Ella244-18/phase-1-project/blob/master/student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Stella wanjiku Iregi
# * Student pace: self paced
# * Scheduled project review date/time: August 3rd
# * Instructor name: Noah Kandie
# * Blog post URL: https://colab.research.google.com/github/Ella244-18/phase-1-project/blob/master/student.ipynb#scrollTo=Sqft3Zr2YYAg

# %% [markdown]
# # **Project Title**
# # Independent Project 1: EDA with Pandas

# %% [markdown]
# # Overview
# This project explores the performance of movies by analyzing dat from IMDB, Rotten Tomatoes, and The Numbers. It focuses on uncovering trends in box office revenue, critic and audience ratings, and key fil attributes like genre and runtime. using python tools such as pandas, Numpy and matplotlib, the data is cleaned, merged and visualized to generate insights. the findings aim to support strategic decisions in film production and marketing by highlighting factors that contribute to both commercial and critical success.

# %% [markdown]
# #Business Problem
# In an industry where millions are invested per production, understanding what drives a film's box office success and critical acclaims remains a persistent challenge. Studios and disributors face uncertainity in predicting audience reception, budgeting effectively and aligning creative choices with market demand.
#
# This project seeks to reduce that ambigguity by analyzing patterns across public movie data, connecting financial performance, genre trends and rating systems to inform smarter investment decisions and tageted content strategies in a highly competitive entertainment market

# %%
#Import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# #Data Preparation

# %% [markdown]
# ##Loading the data separately.

# %%
df1 = pd.read_csv('/content/bom.movie_gross.csv')
df1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df2 = pd.read_csv('/content/title.basics.csv')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df1.head(8)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010
# 7     391000000  2010

# %%
df1.tail()
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df2.tail(4)
# Out:
#            tconst                                primary_title  \
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# 146143              NaN  Documentary

# %%
# Checking the info of the data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# From the above code we see that df1 has **3387** **rows** and **5** **columns**.
#
# We can also see that some columns have missing values.
#
# Studio has **5** missing values, domestic_gross has  **28** and foreign_gross has **1350** missing values

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# in df2 we have 146144 rows and 6 columns

# %%
# Getting our columns
df1.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
df2.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
# Describing the data

# %%
df1.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df2.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %% [markdown]
# ###Merging the two Dataframes

# %%
# Merging by stacking all rows from both datasets
combined_df = pd.concat([df1,df2], ignore_index= True)
combined_df
# Out:
#                                               title studio  domestic_gross  \
# 0                                       Toy Story 3     BV     415000000.0
# 1                        Alice in Wonderland (2010)     BV     334200000.0
# 2       Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                         Inception     WB     292600000.0
# 4                               Shrek Forever After   P/DW     238700000.0
# ...                                             ...    ...             ...
# 149526                                          NaN    NaN             NaN
# 149527                                          NaN    NaN             NaN
# 149528                                          NaN    NaN             NaN
# 149529                                          NaN    NaN             NaN
# 149530                                          NaN    NaN             NaN
#
#        foreign_gross    year     tconst  \
# ...

# %%
combined_df.shape
# Out:
# (149531, 11)

# %%
combined_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross    year tconst primary_title original_title  start_year  \
# 0     652000000  2010.0    NaN           NaN            NaN         NaN
# 1     691300000  2010.0    NaN           NaN            NaN         NaN
# 2     664300000  2010.0    NaN           NaN            NaN         NaN
# 3     535700000  2010.0    NaN           NaN            NaN         NaN
# 4     513900000  2010.0    NaN           NaN            NaN         NaN
#
#    runtime_minutes genres
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# ...

# %% [markdown]
# *   The two datasets contain similar and related columns which make them ideal for concatenation.
#
# *   This method works really well when you want to add more movie entries to your dataset

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##Checking for duplicates

# %%
duplicates = combined_df[combined_df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year, tconst, primary_title, original_title, start_year, runtime_minutes, genres]
# Index: []

# %%
duplicates.shape
# Out:
# (0, 11)

# %% [markdown]
# As seen above, the dataframe has no duplicates
#
# Let's try a different approach and ckeck for duplicate values in specific columns

# %%
combined_df[combined_df.duplicated(subset=['title', 'year'])]
# Out:
#        title studio  domestic_gross foreign_gross  year     tconst  \
# 3388     NaN    NaN             NaN           NaN   NaN  tt0066787
# 3389     NaN    NaN             NaN           NaN   NaN  tt0069049
# 3390     NaN    NaN             NaN           NaN   NaN  tt0069204
# 3391     NaN    NaN             NaN           NaN   NaN  tt0100275
# 3392     NaN    NaN             NaN           NaN   NaN  tt0111414
# ...      ...    ...             ...           ...   ...        ...
# 149526   NaN    NaN             NaN           NaN   NaN  tt9916538
# 149527   NaN    NaN             NaN           NaN   NaN  tt9916622
# 149528   NaN    NaN             NaN           NaN   NaN  tt9916706
# 149529   NaN    NaN             NaN           NaN   NaN  tt9916730
# 149530   NaN    NaN             NaN           NaN   NaN  tt9916754
#
#                                       primary_title  \
# 3388                One Day Before the Rainy Season
# 3389                     The Other Side of the Wind
# ...

# %%
# Remove duplicates based on title and year, keeping the first  one
combined_df = combined_df.drop_duplicates(subset=['title', 'year'], keep='first')
combined_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
# 3387                                          NaN         NaN             NaN
#
# ...

# %% [markdown]
# Having dropped the duplicates, the number of rows have decreased while the number of columns remained the same

# %%
# Change all the column headings to lowercase
combined_df.columns.str.lower()
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year', 'tconst',
#        'primary_title', 'original_title', 'start_year', 'runtime_minutes',
#        'genres'],
#       dtype='object')

# %%
# Check unique values in each column
combined_df.nunique()
# Out:
# title              3386
# studio              257
# domestic_gross     1797
# foreign_gross      1204
# year                  9
# tconst                1
# primary_title         1
# original_title        1
# start_year            1
# runtime_minutes       1
# genres                1
# dtype: int64

# %%
# Check the missing values
combined_df.isna()#Returns true for cells that are not missing
# Out:
#       title  studio  domestic_gross  foreign_gross   year  tconst  \
# 0     False   False           False          False  False    True
# 1     False   False           False          False  False    True
# 2     False   False           False          False  False    True
# 3     False   False           False          False  False    True
# 4     False   False           False          False  False    True
# ...     ...     ...             ...            ...    ...     ...
# 3383  False   False           False           True  False    True
# 3384  False   False           False           True  False    True
# 3385  False   False           False           True  False    True
# 3386  False   False           False           True  False    True
# 3387   True    True            True           True   True   False
#
#       primary_title  original_title  start_year  runtime_minutes  genres
# 0              True            True        True             True    True
# ...

# %%
# Total number of missing values
combined_df.isna().sum()
# Out:
# title                 1
# studio                6
# domestic_gross       29
# foreign_gross      1351
# year                  1
# tconst             3387
# primary_title      3387
# original_title     3387
# start_year         3387
# runtime_minutes    3387
# genres             3387
# dtype: int64

# %%
#Convert 'foreign_gross' to numeric coercing errors to NaN
combined_df['foreign_gross'] = pd.to_numeric(combined_df['foreign_gross'], errors='coerce')

#How to replace the missing values for the numerical columns
combined_df['runtime_minutes'] = combined_df['runtime_minutes'].fillna(combined_df['runtime_minutes'].median())
combined_df['foreign_gross'] = combined_df['foreign_gross'].fillna(combined_df['foreign_gross'].median())
combined_df['domestic_gross'] = combined_df['domestic_gross'].fillna(combined_df['domestic_gross'].mean())
combined_df
# Out:
# /tmp/ipython-input-3978064288.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['foreign_gross'] = pd.to_numeric(combined_df['foreign_gross'], errors='coerce')
# /tmp/ipython-input-3978064288.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['runtime_minutes'] = combined_df['runtime_minutes'].fillna(combined_df['runtime_minutes'].median())
# /tmp/ipython-input-3978064288.py:6: SettingWithCopyWarning:
# ...

# %%
#Filling in the missing values for categorical columns
combined_df['studio'].fillna('Unknown Studio', inplace=True)
combined_df['genres'].fillna('Unclassified', inplace=True)
#For year or start year
combined_df['year'].fillna(combined_df['year'].mode([0]), inplace=True)
combined_df
# Out:
# /tmp/ipython-input-4281502759.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df['studio'].fillna('Unknown Studio', inplace=True)
# /tmp/ipython-input-4281502759.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['studio'].fillna('Unknown Studio', inplace=True)
# ...

# %%
#Drop the rows with missing title or year
combined_df = combined_df.dropna(subset=['title', 'year'])
combined_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
combined_df['movie_title'] = combined_df['primary_title'].combine_first(combined_df['original_title'])
combined_df.drop(columns=['primary_title', 'original_title'], inplace=True)
combined_df
# Out:
# /tmp/ipython-input-2324421655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['movie_title'] = combined_df['primary_title'].combine_first(combined_df['original_title'])
# /tmp/ipython-input-2324421655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df.drop(columns=['primary_title', 'original_title'], inplace=True)
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# ...

# %%
combined_df['movie_title'].fillna(combined_df['title'], inplace=True)
combined_df
# Out:
# /tmp/ipython-input-2408210839.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df['movie_title'].fillna(combined_df['title'], inplace=True)
# /tmp/ipython-input-2408210839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['movie_title'].fillna(combined_df['title'], inplace=True)
# ...

# %%
combined_df.isna().sum()
# Out:
# title                 0
# studio                0
# domestic_gross        0
# foreign_gross         0
# year                  0
# tconst             3387
# start_year         3387
# runtime_minutes       0
# genres                0
# movie_title           0
# dtype: int64

# %% [markdown]
# In the tconst column, we shall leave the null values blank, for further analysis.
#
# As for the start_year column we shall drop it since we already have another almost similar column, year.

# %%
combined_df.drop(columns= ['start_year'], inplace=True)
combined_df
# Out:
# /tmp/ipython-input-1773838445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df.drop(columns= ['start_year'], inplace=True)
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# ...

# %%
combined_df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year', 'tconst',
#        'runtime_minutes', 'genres', 'movie_title'],
#       dtype='object')

# %%
#Check the proportion of missing values per column
missing_proportion = combined_df.isna().mean().round(3) # Calculate the missing proportion and round to 3 decimal places
missing_proportion # Display the missing proportion
# Out:
# title              0.0
# studio             0.0
# domestic_gross     0.0
# foreign_gross      0.0
# year               0.0
# tconst             1.0
# runtime_minutes    0.0
# genres             0.0
# movie_title        0.0
# dtype: float64

# %%
# Get the rows with the missing values
combined_df[combined_df.isnull().any(axis=1)]
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
# Drop the rows with missing values
combined_df.dropna(axis=0, how="all", inplace=True)
combined_df
# Out:
# /tmp/ipython-input-2034576357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df.dropna(axis=0, how="all", inplace=True)
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# ...

# %% [markdown]
# There is no row containing completely missing values.

# %%
#Checking for outliers using seaborn
sns.boxplot(data=combined_df)
plt.title('Box plot of domestic gross vs foreign gross')
plt.show()

# %%
#Checking for outliers using matplotlib
combined_df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# The domestic_gross and foreign_gross column contain many outliers but given this is a movie dataset, we shall keep the outliers since they are a representative of the real data.

# %% [markdown]
# # Feature Engineering

# %%
# Extracting the release year
combined_df['release_year'] = combined_df['year']
combined_df
# Out:
# /tmp/ipython-input-1226767017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['release_year'] = combined_df['year']
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate analysis
# This is the analysis of data that involves one single variable.
#
# It also uses typical plots such as histograms,box plots,bar charts and also pie charts.

# %%
# Let's first check the statistical summaries
combined_df.describe()
# Out:
#        domestic_gross  foreign_gross         year  runtime_minutes  \
# count    3.387000e+03   3.387000e+03  3387.000000           3387.0
# mean     2.874585e+07   5.259091e+07  2013.958075            175.0
# std      6.670497e+07   1.100108e+08     2.478141              0.0
# min      1.000000e+02   6.000000e+02  2010.000000            175.0
# 25%      1.225000e+05   1.175000e+07  2012.000000            175.0
# 50%      1.400000e+06   1.890000e+07  2014.000000            175.0
# 75%      2.874585e+07   2.915000e+07  2016.000000            175.0
# max      9.367000e+08   9.605000e+08  2018.000000            175.0
#
#        release_year
# count   3387.000000
# mean    2013.958075
# std        2.478141
# min     2010.000000
# 25%     2012.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2018.000000

# %% [markdown]
# The earliest year for a movie was 2010 while the latest year for a movie is 2018.
#
# Tho total runtime minutes is 3387 minutes.
#
# The above summarizes the mean, standard deviation and a lot of statistics for the dataset.

# %%
# Let's calculate the measures of central tendencies
# We will just use their functions
combined_df.mean(numeric_only=True)
# Out:
# domestic_gross     2.874585e+07
# foreign_gross      5.259091e+07
# year               2.013958e+03
# runtime_minutes    1.750000e+02
# release_year       2.013958e+03
# dtype: float64

# %%
combined_df.median(numeric_only=True)
# Out:
# domestic_gross      1400000.0
# foreign_gross      18900000.0
# year                   2014.0
# runtime_minutes         175.0
# release_year           2014.0
# dtype: float64

# %%
combined_df.mode(numeric_only=True)
# Out:
#    domestic_gross  foreign_gross    year  runtime_minutes  release_year
# 0       1100000.0     18900000.0  2015.0            175.0        2015.0

# %%
combined_df.var(numeric_only=True)
# Out:
# domestic_gross     4.449553e+15
# foreign_gross      1.210237e+16
# year               6.141183e+00
# runtime_minutes    0.000000e+00
# release_year       6.141183e+00
# dtype: float64

# %%
combined_df.std(numeric_only=True)
# Out:
# domestic_gross     6.670497e+07
# foreign_gross      1.100108e+08
# year               2.478141e+00
# runtime_minutes    0.000000e+00
# release_year       2.478141e+00
# dtype: float64

# %% [markdown]
# ##Skewness
# Skewness measures the asymmerty of a distribution around its mean.
# It tells you how symmetrical your data is or not.
# ***In a normal curve skewness is 0***

# %%
combined_df.skew(numeric_only=True)
# Out:
# domestic_gross     4.739646
# foreign_gross      4.188992
# year              -0.007425
# runtime_minutes    0.000000
# release_year      -0.007425
# dtype: float64

# %%
# Let's plot a plot using histograms
combined_df.hist()
plt.figure(figsize=(10,10))

# %% [markdown]
# ## Kurtosis
# Kurtosis measures the **tailedness** of a distribution. It tells you how peaked or flat your distribution is compared to a normal curve.
#
# ***A standard normal distribution has a kurtosis of 3***

# %%
combined_df.kurt(numeric_only=True)
# Out:
# domestic_gross     32.839566
# foreign_gross      20.486789
# year               -1.158922
# runtime_minutes     0.000000
# release_year       -1.158922
# dtype: float64

# %%
# Let's now calculate how many of each unique values are in the columns
year = combined_df['year'].value_counts()
year
# Out:
# year
# 2015.0    450
# 2016.0    436
# 2012.0    400
# 2011.0    399
# 2014.0    395
# 2013.0    350
# 2010.0    328
# 2017.0    321
# 2018.0    308
# Name: count, dtype: int64

# %% [markdown]
# Using **value_counts** function returns objects containing counts of unique values.

# %%
# Now let's check the most popular studio
combined_df['studio'].value_counts().head(10)
# Out:
# studio
# IFC      166
# Uni.     147
# WB       140
# Fox      136
# Magn.    136
# SPC      123
# Sony     110
# BV       106
# LGF      103
# Par.     101
# Name: count, dtype: int64

# %% [markdown]
# **Studios IFC, uni., WB** and **Fox** are the most popular studios.

# %%
combined_df['studio'].value_counts().tail(10)
# Out:
# studio
# MOM           1
# CFI           1
# UTMW          1
# Crimson       1
# CAVU          1
# EF            1
# Arrow         1
# Hiber         1
# PDF           1
# Synergetic    1
# Name: count, dtype: int64

# %% [markdown]
# This now shows us the list of the 10 unpopular studios

# %%
# Histogram
plt.hist(combined_df['domestic_gross'], bins=30, color='skyblue', edgecolor='black')
plt.title('Domestic Gross Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot
sns.boxplot(data= combined_df['foreign_gross'], color='lightcoral')
plt.title('Box Plot Of Foreign Gross Prices')
plt.show()

# %% [markdown]
# Foreign gross has very many outliers

# %%
# Strip plot
sns.stripplot(data=combined_df['domestic_gross'], color='purple', alpha=0.5)
plt.title('domestic Gross Strip Plot')
plt.show()

# %% [markdown]
# A strip plot shows a dot-like view if individual observations and is used to visualize concentration and outliers.

# %%
# Piechart
combined_df['release_year'].value_counts().plot(kind='pie',autopct = '%1.2f%%')
plt.title('Release year')
# Out:
# Text(0.5, 1.0, 'Release year')

# %% [markdown]
# ## Bivariate Analysis
# This is analysis that studies the relationship between two variables in order to see how one variable influences or relates to another.
#
# Typical plots used are scatter plots, line charts and analysis include correlation and also covariance

# %% [markdown]
# **Correlation** is the statistical summary of the relationship between variables.
#
# *   Positive correlation: both variables change in the same direction.
# *   Neutral correlation: No relationship in the change of the variables.
#
# *   Negative correlation: variables change in opposite directions.

# %%
combined_df.corr(numeric_only=True)
# Out:
#                  domestic_gross  foreign_gross      year  runtime_minutes  \
# domestic_gross         1.000000       0.785335  0.018640              NaN
# foreign_gross          0.785335       1.000000  0.057189              NaN
# year                   0.018640       0.057189  1.000000              NaN
# runtime_minutes             NaN            NaN       NaN              NaN
# release_year           0.018640       0.057189  1.000000              NaN
#
#                  release_year
# domestic_gross       0.018640
# foreign_gross        0.057189
# year                 1.000000
# runtime_minutes           NaN
# release_year         1.000000

# %%
# Correlation Heatmap
plt.figure(figsize=(11,6))
heatmap = sns.heatmap(combined_df.corr(numeric_only=True),annot=True, cmap='viridis')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# **Correlation heatmaps** contain the same information in a visually appealing way.
#
# They show in a glance which variables are correlated, to what degree, in which direction, and alerts us to potential multicollinearity.
#
# From the heatmap;
#
#
# *   +1... shows perfect positive correlation (as one increases, so does the other)
# *  0... shows no linear correlation.
#
#
#
# *   -1... shows perfect negative correlation (as one increases, the other decreases)

# %%
plt.figure(figsize=(8,12))
heatmap = sns.heatmap(combined_df.corr(numeric_only=True), annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':16}, pad=15)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# # Lineplot
sns.lineplot(data=combined_df,x=combined_df['domestic_gross'],y=combined_df['foreign_gross'])
plt.title('Lineplot of Domestic Gross Vs Foreign Gross')
plt.show()

# %%
# Scatter Plot
plt.scatter(combined_df['foreign_gross'], combined_df['domestic_gross'], alpha=0.6, color='tomato')
plt.title('Foreign Gross vs Domestic Gross')
plt.xlabel('Domestic Gross')
plt.ylabel('Foreign Gross')
plt.grid=True
plt.show()

# %%
# Boxplot
sns.boxplot(x='genres', y='foreign_gross', data=combined_df)
plt.title('Foreign Gross vs Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Conclusion. limitations and next steps.
#
#
# *  **Limitations** encountered include potential biases in dataset coverage, missing  values, and the absence of predictive modelling.
#
#
# *   In **conclusion**, my project successfully demonstrates a  structured, insightful approach to turning raw movie data into actionable business recommendations , laying the foundation for more advanced analysis and industry- relevant storytelling.
#
#
# *   **Next steps** include expanding to to international
# market data or exploring time-based revenue forecasting.

# %% [markdown]
# # Recommendations
#
# 1.   Studios should create targeted , genre-specific marketing campaigns and explore underrepresented genres with strong audience loyalty.
#
# 2.   Use metadata (genre+ country performance) to plan tiered international rollouts tailored to regional tastes.
#
# 3.  Use historical pairing (eg. of actors) trends to inform casting for new franchise or original stories.
#
# 4.   Develop low- budget versions of different genres with contemporary twists.
